# %%
# !pip install wordcloud

# %%
text="""Data sceince at CREST Technology"""

wordcloud=WordCloud(width=800, height=400, background_color ="white").generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# !pip install plotly

# %%
# !pip install virtualenv
# Out:
# ...
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.0 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/6.0 MB 1.3 MB/s eta 0:00:04
#    ------- -------------------------------- 1.0/6.0 MB 1.2 MB/s eta 0:00:05
#    -------- ------------------------------- 1.3/6.0 MB 1.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.6/6.0 MB 1.3 MB/s eta 0:00:04
#    -------------- ------------------------- 2.1/6.0 MB 1.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.6/6.0 MB 1.5 MB/s eta 0:00:03
#    --------------------- ------------------ 3.1/6.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 3.7/6.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.2/6.0 MB 1.8 MB/s eta 0:00:02
# ...

# %%
#reading csv file
import pandas as pd
import seaborn as sns
import plotly.express as px

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(10,6)

df=pd.read_csv(r"D:\pythonML-class\netflix_titles_sample.csv")
print("Shape of dataset:",df.shape)
print(df.head())
# Out:
# Shape of dataset: (10, 12)
#   show_id     type            title           director  \
# 0      s1    Movie        Inception  Christopher Nolan
# 1      s2  TV Show  Stranger Things            Unknown
# 2      s3    Movie     The Irishman    Martin Scorsese
# 3      s4    Movie       Extraction       Sam Hargrave
# 4      s5  TV Show             Dark            Unknown
#
#                                       cast  country         date_added  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt      USA  September 1, 2020
# 1        Millie Bobby Brown, Finn Wolfhard      USA      July 15, 2016
# 2                Robert De Niro, Al Pacino      USA  November 27, 2019
# 3           Chris Hemsworth, Randeep Hooda      USA     April 24, 2020
# 4               Louis Hofmann, Lisa Vicari  Germany   December 1, 2017
#
#    release_year rating   duration                 listed_in  \
# 0          2010  PG-13    148 min  Sci-Fi & Fantasy, Action
# ...

# %%
df['director'].fillna("Unknown", inplace=True)
df['Cast'].fillna("Unknown",inplace=True)
df['country'].fillna("Unknown",inplace=True)
df['rating'].fillna("Unknown",inplace=True)
df['date_added']=pd.to_datetime(df['date_added'],errors='coerce')
df['date_added']=pd.fillna(pd.Timestamp("1900-01-01"))

# %%
sns.countplot(x='type', data=df, palette="Set2")
plt.title("Movies")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19516\1039338932.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=df, palette="Set2")

# %%
top_countries=df['country'].value_counts().nlargest(10)
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title("top 10 content")
plt.xlabel("No of titles")
plt.ylabel("Countries")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19516\1368452684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')

# %%
fig=px.histogram(df,x="release_year",color="type",barmode="group",title="Movies vs TV shows")
fig.show()

# %% [markdown]
# # # **Given assignment**

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(10,6)

df=pd.read_csv(r"D:\pythonML-class\netflix_titles_sample.csv")
print("Shape of dataset:",df.shape)
print(df.head())
# Out:
# Shape of dataset: (10, 12)
#   show_id     type            title           director  \
# 0      s1    Movie        Inception  Christopher Nolan
# 1      s2  TV Show  Stranger Things            Unknown
# 2      s3    Movie     The Irishman    Martin Scorsese
# 3      s4    Movie       Extraction       Sam Hargrave
# 4      s5  TV Show             Dark            Unknown
#
#                                       cast  country         date_added  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt      USA  September 1, 2020
# 1        Millie Bobby Brown, Finn Wolfhard      USA      July 15, 2016
# 2                Robert De Niro, Al Pacino      USA  November 27, 2019
# 3           Chris Hemsworth, Randeep Hooda      USA     April 24, 2020
# 4               Louis Hofmann, Lisa Vicari  Germany   December 1, 2017
#
#    release_year rating   duration                 listed_in  \
# 0          2010  PG-13    148 min  Sci-Fi & Fantasy, Action
# ...

# %% [markdown]
# # **distribution of rating**

# %%
# Distribution of rating
sns.countplot(x='rating', data=df, order=df['rating'].value_counts().index, palette="coolwarm")
plt.title("Distribution of Ratings")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22036\4259961180.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # **titles added per year**

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year
sns.countplot(x='year_added', data=df, palette="viridis")
plt.title("Titles Added Per Year")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22036\2238730300.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # **top 10 longest movies**

# %%
movies = df[df['type'] == 'Movie'].copy()
# Extract duration for numbers and intigers
movies['duration_int'] = movies['duration'].str.split().str[0].astype(float)
top10 = movies.nlargest(10, 'duration_int')
sns.barplot(x='title', y='duration_int', data=top10, palette="crest")
plt.title("Top 10 Longest Movies")
plt.xlabel("Movie Title")
plt.ylabel("Duration (minutes)")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22036\4132647066.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # **interactive visualization with plotly**

# %%
fig=px.histogram(df,x="release_year",color="type",barmode="group",title="Movies vs TV shows")
fig.show()

# %% [markdown]
# # **pairplot**

# %%
sns.pairplot(movies[['release_year', 'duration_int']].dropna())
plt.suptitle("Pairplot: Release Year vs Duration (Movies)")
plt.show()
